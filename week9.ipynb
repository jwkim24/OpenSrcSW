# %%
# 실습문제 1번
x = int(input("x 값을 입력해주세요 : "))
y = 3*x*x + 5*x + 3
print("y의 값은 :",y);
# Out:
# x 값을 입력해주세요 : 1
# y의 값은 : 11

# %%
# 실습문제 2번
r = float(input("반지름의 길이를 입력해주세요 : "))
pi = 3.14
l = 2*pi*r
y = pi*r*r
print("원의 둘레 : ", l)
print("원의 넓이 : ", y)
# Out:
# 반지름의 길이를 입력해주세요 : 1
# 원의 둘레 :  6.28
# 원의 넓이 :  3.14
